# %%
from datetime import datetime as dt
import folium
import os
import sys
sys.path.insert(0, '..')
import tarfile
import requests
from utils import DataLoader


dl = DataLoader()
dfs = dl.fetch_virus_data()

# %%
dl.df_zip

# %%
# Out:
# {'case-hosp-death':    DATE_OF_INTEREST  NEW_COVID_CASE_COUNT  HOSPITALIZED_CASE_COUNT  \
#  0            3/2/20                     1                      4.0
#  1            3/3/20                     2                      3.0
#  2            3/4/20                    10                      5.0
#  3            3/5/20                     2                      4.0
#  4            3/6/20                     8                      5.0
#  5            3/7/20                    13                      9.0
#  6            3/8/20                    20                     12.0
#  7            3/9/20                    53                     24.0
#  8           3/10/20                    70                     38.0
#  9           3/11/20                   156                     56.0
#  10          3/12/20                   356                     62.0
#  11          3/13/20                   612                    121.0
# ...

# %%
    
    folium.Marker(
        location=[lat, lng],
        popup=f'total: {total}\npositive: {positive}',
        tooltip = k
    ).add_to(ny)
ny
# Out:
#   File "<ipython-input-136-7ae2eb59eb1c>", line 3
#     folium.Marker(
#     ^
# IndentationError: unexpected indent
